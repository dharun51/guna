# %%
print("🫦 welcome to your simple cute chatbot")
print("answer the questions by typing a or b\n")

score = 0

questions = [
    {
        "question": "1. What is the capital of India?",
        "a": "Mumbai",
        "b": "Delhi",
        "answer": "b"
    },
    {
        "question": "2. Which is the longest river in the world?",
        "a": "Nile River",
        "b": "Ganga River",
        "answer": "a"
    },
    {
        "question": "3. What is the capital city of Australia?",
        "a": "Tokyo",
        "b": "Canberra",
        "answer": "b"
    },
    {
        "question": "4. Which planet is known as the red planet?",
        "a": "Mars",
        "b": "Moon",
        "answer": "a"
    },
    {
        "question": "5. Who was the first woman to fly solo across the Atlantic Ocean?",
        "a": "Amelia Earhart",
        "b": "None of these",
        "answer": "a"
    },
    {
        "question": "6. In which year did the Titanic sink?",
        "a": "1912",
        "b": "1324",
        "answer": "a"
    },
    {
        "question": "7. Which is the largest desert in the world?",
        "a": "Gobi",
        "b": "Antarctic Desert",
        "answer": "b"
    },
    {
        "question": "8. Who was the first President of India?",
        "a": "Rajendra Prasad",
        "b": "Zakir Husain",
        "answer": "a"
    },
    {
        "question": "9. Which country won the FIFA World Cup in 2022?",
        "a": "Argentina",
        "b": "Brazil",
        "answer": "a"
    }
]

for q in questions:
    print(q["question"])
    print("a)", q["a"])
    print("b)", q["b"])
    user_ans = input("Your answer: ").lower()
    if user_ans == q["answer"]:
        print("👌 Correct!\n")
        score += 1
    else:
        print("Wrong! Correct answer:", q["answer"], "\n")

print("Your final score:", score, "/", len(questions))
# Out:
# 🫦 welcome to your simple cute chatbot
# answer the questions by typing a or b
#
# 1. What is the capital of India?
# a) Mumbai
# b) Delhi
# Your answer:  b
# 👌 Correct!
#
# 2. Which is the longest river in the world?
# a) Nile River
# b) Ganga River
# Your answer:  a
# 👌 Correct!
#
# 3. What is the capital city of Australia?
# a) Tokyo
# b) Canberra
# Your answer:  b
# 👌 Correct!
#
# 4. Which planet is known as the red planet?
# a) Mars
# b) Moon
# Your answer:  a
# 👌 Correct!
#
# 5. Who was the first woman to fly solo across the Atlantic Ocean?
# a) Amelia Earhart
# b) None of these
# Your answer:  a
# 👌 Correct!
#
# 6. In which year did the Titanic sink?
# a) 1912
# b) 1324
# Your answer:  a
# 👌 Correct!
#
# 7. Which is the largest desert in the world?
# a) Gobi
# b) Antarctic Desert
# Your answer:  a
# Wrong! Correct answer: b
#
# 8. Who was the first President of India?
# a) Rajendra Prasad
# b) Zakir Husain
# Your answer:  b
# Wrong! Correct answer: a
#
# ...
